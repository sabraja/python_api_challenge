# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import random
import scipy.stats as st

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %%
# Generating a list of 500 cities at about equal latitudes, random longitudes
city_list=[]

#adding x iterations through whole range of latitudes
x=2000
for instance in range(int(-x/2),int(x/2)):
    #considering corresponding latitude proportional to the number of iterations
    lat=instance*90/(x/2)
    
    # considering random longitudes within the whole range
    long=random.uniform(-180,180)
    
    city=citipy.nearest_city(lat,long)
    
    # adding only unique items
    if (city.city_name,city.country_code) not in city_list:
        city_list.append((city.city_name,city.country_code))
len(city_list)

# Create blank dataframe
city_data_df=pd.DataFrame(city_list)
city_data_df=city_data_df.rename(columns={0:"City",1:"Country Code"})
city_data_df["Lat [deg]"]=""
city_data_df["Long [deg]"]=""
city_data_df["Temperature [F]"]=""
city_data_df["Humidity [%]"]=""
city_data_df["Cloudiness [%]"]=""
city_data_df["Wind Speed [mph]"]=""

city_data_df
# Out:
#               City Country Code Lat [deg] Long [deg] Temperature [F]  \
# 0          rikitea           pf
# 1           albany           au
# 2      port alfred           za
# 3          mataura           pf
# 4          ushuaia           ar
# ..             ...          ...       ...        ...             ...
# 759        qaanaaq           gl
# 760         narsaq           gl
# 761  belushya guba           ru
# 762   longyearbyen           sj
# 763      ostrovnoy           ru
#
#     Humidity [%] Cloudiness [%] Wind Speed [mph]
# 0
# 1
# 2
# 3
# 4
# ..           ...            ...              ...
# 759
# 760
# 761
# 762
# 763
#
# [764 rows x 8 columns]

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# # Perform API Calls
#
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : yulara
# Processing Record 2 of Set 1 : ponta do sol
# Processing Record 3 of Set 1 : belyy yar
# Processing Record 4 of Set 1 : colorado
# Processing Record 5 of Set 1 : lebu
# Processing Record 6 of Set 1 : ushuaia
# Processing Record 7 of Set 1 : cape town
# Processing Record 8 of Set 1 : new norfolk
# Processing Record 9 of Set 1 : tasiilaq
# Processing Record 10 of Set 1 : saint-philippe
# Processing Record 11 of Set 1 : busselton
# City not found. Skipping...
# Processing Record 12 of Set 1 : hermanus
# Processing Record 13 of Set 1 : coquimbo
# Processing Record 14 of Set 1 : faanui
# Processing Record 15 of Set 1 : barrow
# Processing Record 16 of Set 1 : verkhnedneprovskiy
# Processing Record 17 of Set 1 : saint george
# Processing Record 18 of Set 1 : bluff
# City not found. Skipping...
# Processing Record 19 of Set 1 : avera
# Processing Record 20 of Set 1 : tuktoyaktuk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 1 : punta arenas
# Processing Record 22 of Set 1 : rikitea
# Processing Record 23 of Set 1 : cherskiy
# Processing Record 24 of Set 1 : omsukchan
# Processing Record 25 of Set 1 : the valley
# Processing Record 26 of Set 1 : guerrero negro
# Processing Record 27 of Set 1 : alamosa
# Processing Record 28 of Set 1 : mar del plata
# Processing Record 29 of Set 1 : la cruz
# Processing Record 30 of Set 1 : longjiang
# Processing Record 31 of Set 1 : puerto ayora
# Processing Record 32 of Set 1 : tuatapere
# Processing Record 33 of Set 1 : sao jose da coroa grande
# Processing Record 34 of Set 1 : dospat
# Processing Record 35 of Set 1 : kodiak
# Processing Record 36 of Set 1 : tomatlan
# Processing Record 37 of Set 1 : merauke
# Processing Record 38 of Set 1 : fairbanks
# Processing Record 39 of Set 1 : georgetown
# Processing Record 40 of Set 1 : codrington
# Processing Record 41 of Set 1 : vaini
# Processing Record 42 of Set 1 : mataura
# Processing Record 43 of Set 1 : kapaa
# Processing Record 44 of Set 1 : hobart
# Processing Record 45 of Set 1 : poum
# City not found. Skipping...
# Processing Record 46 of Set 1 : novobirilyussy
# Processing Record 47 of Set 1 : paamiut
# Processing Record 48 of Set 1 : port lincoln
# Processing Record 49 of Set 1 : taoudenni
# Processing Record 50 of Set 1 : arraial do cabo
# Processing Record 0 of Set 2 : atuona
# Processing Record 1 of Set 2 : pangnirtung
# Processing Record 2 of Set 2 : alice springs
# Processing Record 3 of Set 2 : victoria
# Processing Record 4 of Set 2 : yatou
# Processing Record 5 of Set 2 : libreville
# Processing Record 6 of Set 2 : mount gambier
# Processing Record 7 of Set 2 : qaanaaq
# Processing Record 8 of Set 2 : fort nelson
# Processing Record 9 of Set 2 : ostrovnoy
# Processing Record 10 of Set 2 : lorengau
# City not found. Skipping...
# Processing Record 11 of Set 2 : adre
# City not found. Skipping...
# Processing Record 12 of Set 2 : grand-santi
# Processing Record 13 of Set 2 : pevek
# Processing Record 14 of Set 2 : villa carlos paz
# City not found. Skipping...
# Processing Record 15 of Set 2 : dunedin
# Processing Record 16 of Set 2 : longyearbyen
# Processing Record 17 of Set 2 : barcelos
# Processing Record 18 of Set 2 : gualeguaychu
# Processing Record 19 of Set 2 : penzance
# Processing Record 20 of Set 2 : baruun-urt
# Processing Record 21 of Set 2 : cidreira
# Processing Record 22 of Set 2 : bredasdorp
# Processing Record 23 of Set 2 : lakes entrance
# Processing Record 24 of Set 2 : ler
# Processing Record 25 of Set 2 : stykkisholmur
# Processing Record 26 of Set 2 : san patricio
# Processing Record 27 of Set 2 : saskylakh
# Processing Record 28 of Set 2 : torbay
# Processing Record 29 of Set 2 : kibre mengist
# Processing Record 30 of Set 2 : northam
# City not found. Skipping...
# Processing Record 31 of Set 2 : albany
# Processing Record 32 of Set 2 : marzuq
# Processing Record 33 of Set 2 : goderich
# Processing Record 34 of Set 2 : pemba
# Processing Record 35 of Set 2 : xingcheng
# Processing Record 36 of Set 2 : souillac
# Processing Record 37 of Set 2 : zhigansk
# Processing Record 38 of Set 2 : north ogden
# Processing Record 39 of Set 2 : camapua
# Processing Record 40 of Set 2 : acapulco
# Processing Record 41 of Set 2 : san cristobal
# Processing Record 42 of Set 2 : pedernales
# Processing Record 43 of Set 2 : katobu
# Processing Record 44 of Set 2 : sorland
# Processing Record 45 of Set 2 : caravelas
# Processing Record 46 of Set 2 : hilo
# Processing Record 47 of Set 2 : ketchikan
# Processing Record 48 of Set 2 : chuy
# City not found. Skipping...
# Processing Record 49 of Set 2 : yellowknife
# Processing Record 50 of Set 2 : mahebourg
# Processing Record 0 of Set 3 : rocha
# Processing Record 1 of Set 3 : nelson bay
# Processing Record 2 of Set 3 : port hardy
# Processing Record 3 of Set 3 : ossora
# Processing Record 4 of Set 3 : kotovo
# Processing Record 5 of Set 3 : east london
# Processing Record 6 of Set 3 : dingle
# Processing Record 7 of Set 3 : narsaq
# City not found. Skipping...
# Processing Record 8 of Set 3 : namatanai
# Processing Record 9 of Set 3 : tiksi
# Processing Record 10 of Set 3 : baykit
# Processing Record 11 of Set 3 : mitu
# Processing Record 12 of Set 3 : kaitangata
# Processing Record 13 of Set 3 : cabo san lucas
# Processing Record 14 of Set 3 : vicuna
# Processing Record 15 of Set 3 : anloga
# Processing Record 16 of Set 3 : thompson
# Processing Record 17 of Set 3 : salalah
# Processing Record 18 of Set 3 : antofagasta
# Processing Record 19 of Set 3 : castro
# Processing Record 20 of Set 3 : kavieng
# Processing Record 21 of Set 3 : mehamn
# Processing Record 22 of Set 3 : jamestown
# Processing Record 23 of Set 3 : bambous virieux
# Processing Record 24 of Set 3 : tilbury
# Processing Record 25 of Set 3 : bubaque
# Processing Record 26 of Set 3 : namibe
# Processing Record 27 of Set 3 : nome
# Processing Record 28 of Set 3 : berezniki
# Processing Record 29 of Set 3 : lashio
# City not found. Skipping...
# Processing Record 30 of Set 3 : hobyo
# Processing Record 31 of Set 3 : sao filipe
# Processing Record 32 of Set 3 : rosario oeste
# Processing Record 33 of Set 3 : abu samrah
# Processing Record 34 of Set 3 : along
# Processing Record 35 of Set 3 : flinders
# Processing Record 36 of Set 3 : tashigang
# Processing Record 37 of Set 3 : ribeira grande
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 3 : bonavista
# Processing Record 39 of Set 3 : viedma
# Processing Record 40 of Set 3 : normandin
# Processing Record 41 of Set 3 : selje
# Processing Record 42 of Set 3 : brownsville
# Processing Record 43 of Set 3 : konza
# Processing Record 44 of Set 3 : sur
# Processing Record 45 of Set 3 : bandarbeyla
# Processing Record 46 of Set 3 : voyinka
# Processing Record 47 of Set 3 : palmer
# Processing Record 48 of Set 3 : marawi
# Processing Record 49 of Set 3 : calafell
# Processing Record 50 of Set 3 : santa isabel do rio negro
# City not found. Skipping...
# Processing Record 0 of Set 4 : billings
# Processing Record 1 of Set 4 : brokopondo
# Processing Record 2 of Set 4 : hithadhoo
# Processing Record 3 of Set 4 : charters towers
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 4 : butaritari
# Processing Record 5 of Set 4 : tyube
# Processing Record 6 of Set 4 : beni suef
# Processing Record 7 of Set 4 : college station
# Processing Record 8 of Set 4 : hasaki
# Processing Record 9 of Set 4 : klaksvik
# Processing Record 10 of Set 4 : vysokogornyy
# Processing Record 11 of Set 4 : kuah
# Processing Record 12 of Set 4 : grants
# Processing Record 13 of Set 4 : emerald
# Processing Record 14 of Set 4 : camacha
# Processing Record 15 of Set 4 : harper
# Processing Record 16 of Set 4 : beringovskiy
# Processing Record 17 of Set 4 : devarkonda
# Processing Record 18 of Set 4 : markova
# Processing Record 19 of Set 4 : cooma
# Processing Record 20 of Set 4 : san isidro
# Processing Record 21 of Set 4 : zambezi
# Processing Record 22 of Set 4 : monastyrshchina
# Processing Record 23 of Set 4 : athabasca
# Processing Record 24 of Set 4 : kamaishi
# Processing Record 25 of Set 4 : te anau
# Processing Record 26 of Set 4 : bambanglipuro
# Processing Record 27 of Set 4 : parana
# Processing Record 28 of Set 4 : tual
# Processing Record 29 of Set 4 : nanortalik
# Processing Record 30 of Set 4 : bereda
# City not found. Skipping...
# Processing Record 31 of Set 4 : passo de camaragibe
# Processing Record 32 of Set 4 : tazovskiy
# Processing Record 33 of Set 4 : awjilah
# Processing Record 34 of Set 4 : terrace bay
# Processing Record 35 of Set 4 : tabuk
# Processing Record 36 of Set 4 : juneau
# Processing Record 37 of Set 4 : honningsvag
# Processing Record 38 of Set 4 : lakatoro
# Processing Record 39 of Set 4 : belaya gora
# Processing Record 40 of Set 4 : henties bay
# City not found. Skipping...
# Processing Record 41 of Set 4 : provideniya
# Processing Record 42 of Set 4 : bengkulu
# Processing Record 43 of Set 4 : carnarvon
# Processing Record 44 of Set 4 : caico
# Processing Record 45 of Set 4 : khatanga
# Processing Record 46 of Set 4 : warwick
# Processing Record 47 of Set 4 : jumla
# Processing Record 48 of Set 4 : kirakira
# Processing Record 49 of Set 4 : zheleznodorozhnyy
# City not found. Skipping...
# Processing Record 50 of Set 4 : luderitz
# Processing Record 0 of Set 5 : sitka
# City not found. Skipping...
# Processing Record 1 of Set 5 : bilibino
# Processing Record 2 of Set 5 : garowe
# Processing Record 3 of Set 5 : skibbereen
# Processing Record 4 of Set 5 : tautira
# Processing Record 5 of Set 5 : springbok
# Processing Record 6 of Set 5 : dikson
# Processing Record 7 of Set 5 : cayenne
# Processing Record 8 of Set 5 : san ramon
# City not found. Skipping...
# Processing Record 9 of Set 5 : westport
# Processing Record 10 of Set 5 : tara
# Processing Record 11 of Set 5 : puro
# Processing Record 12 of Set 5 : galesong
# Processing Record 13 of Set 5 : salinopolis
# Processing Record 14 of Set 5 : grindavik
# Processing Record 15 of Set 5 : vestmanna
# Processing Record 16 of Set 5 : sandwick
# Processing Record 17 of Set 5 : karaton
# Processing Record 18 of Set 5 : ingham
# City not found. Skipping...
# Processing Record 19 of Set 5 : padang
# Processing Record 20 of Set 5 : san roque
# Processing Record 21 of Set 5 : ambilobe
# Processing Record 22 of Set 5 : margate
# Processing Record 23 of Set 5 : shchors
# Processing Record 24 of Set 5 : chokurdakh
# Processing Record 25 of Set 5 : manado
# Processing Record 26 of Set 5 : siguiri
# Processing Record 27 of Set 5 : agadir
# Processing Record 28 of Set 5 : pokhara
# Processing Record 29 of Set 5 : port macquarie
# City not found. Skipping...
# Processing Record 30 of Set 5 : pancas
# Processing Record 31 of Set 5 : kefamenanu
# Processing Record 32 of Set 5 : kruisfontein
# Processing Record 33 of Set 5 : alamogordo
# Processing Record 34 of Set 5 : lufilufi
# Processing Record 35 of Set 5 : chegdomyn
# Processing Record 36 of Set 5 : xining
# Processing Record 37 of Set 5 : kahului
# Processing Record 38 of Set 5 : buala
# Processing Record 39 of Set 5 : kawalu
# Processing Record 40 of Set 5 : ouango
# Processing Record 41 of Set 5 : troitsko-pechorsk
# Processing Record 42 of Set 5 : isangel
# Processing Record 43 of Set 5 : prieska
# Processing Record 44 of Set 5 : nikolskoye
# Processing Record 45 of Set 5 : port elizabeth
# City not found. Skipping...
# Processing Record 46 of Set 5 : kuching
# Processing Record 47 of Set 5 : van
# Processing Record 48 of Set 5 : soe
# Processing Record 49 of Set 5 : olafsvik
# Processing Record 50 of Set 5 : yuanping
# Processing Record 0 of Set 6 : lompoc
# Processing Record 1 of Set 6 : romodanovo
# Processing Record 2 of Set 6 : clinton
# Processing Record 3 of Set 6 : puerto cabezas
# City not found. Skipping...
# Processing Record 4 of Set 6 : akkermanovka
# Processing Record 5 of Set 6 : ilulissat
# Processing Record 6 of Set 6 : camalu
# Processing Record 7 of Set 6 : catuday
# City not found. Skipping...
# Processing Record 8 of Set 6 : buraydah
# Processing Record 9 of Set 6 : puerto ayacucho
# Processing Record 10 of Set 6 : laon
# Processing Record 11 of Set 6 : balkanabat
# Processing Record 12 of Set 6 : turtas
# Processing Record 13 of Set 6 : rio grande
# Processing Record 14 of Set 6 : agarak
# Processing Record 15 of Set 6 : bathsheba
# Processing Record 16 of Set 6 : arman
# Processing Record 17 of Set 6 : yarmouth
# Processing Record 18 of Set 6 : lahaina
# Processing Record 19 of Set 6 : shakiso
# Processing Record 20 of Set 6 : santa cruz
# Processing Record 21 of Set 6 : ipixuna
# Processing Record 22 of Set 6 : laguna
# Processing Record 23 of Set 6 : maniitsoq
# Processing Record 24 of Set 6 : shangqiu
# Processing Record 25 of Set 6 : itoman
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 6 : vao
# Processing Record 27 of Set 6 : puerto baquerizo moreno
# Processing Record 28 of Set 6 : vestmannaeyjar
# Processing Record 29 of Set 6 : fortuna
# Processing Record 30 of Set 6 : katsuura
# Processing Record 31 of Set 6 : kralendijk
# Processing Record 32 of Set 6 : bereznik
# Processing Record 33 of Set 6 : port-gentil
# Processing Record 34 of Set 6 : mayachnyy
# Processing Record 35 of Set 6 : port alfred
# Processing Record 36 of Set 6 : mangai
# Processing Record 37 of Set 6 : hamilton
# Processing Record 38 of Set 6 : pangody
# Processing Record 39 of Set 6 : sulangan
# Processing Record 40 of Set 6 : airai
# Processing Record 41 of Set 6 : gamba
# Processing Record 42 of Set 6 : sola
# Processing Record 43 of Set 6 : hun
# Processing Record 44 of Set 6 : esperance
# Processing Record 45 of Set 6 : brookhaven
# Processing Record 46 of Set 6 : tankhoy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 6 : lavrentiya
# Processing Record 48 of Set 6 : ierapetra
# Processing Record 49 of Set 6 : kandara
# Processing Record 50 of Set 6 : pangai
# Processing Record 0 of Set 7 : leeton
# Processing Record 1 of Set 7 : vieux-habitants
# Processing Record 2 of Set 7 : korla
# Processing Record 3 of Set 7 : babu
# Processing Record 4 of Set 7 : edd
# Processing Record 5 of Set 7 : joetsu
# Processing Record 6 of Set 7 : sibolga
# Processing Record 7 of Set 7 : creel
# Processing Record 8 of Set 7 : ahuimanu
# Processing Record 9 of Set 7 : touros
# Processing Record 10 of Set 7 : bilma
# Processing Record 11 of Set 7 : upernavik
# Processing Record 12 of Set 7 : sao joao da barra
# Processing Record 13 of Set 7 : cascais
# Processing Record 14 of Set 7 : naze
# City not found. Skipping...
# Processing Record 15 of Set 7 : tarko-sale
# Processing Record 16 of Set 7 : nhulunbuy
# Processing Record 17 of Set 7 : teguldet
# Processing Record 18 of Set 7 : makakilo city
# Processing Record 19 of Set 7 : brainerd
# Processing Record 20 of Set 7 : svetlogorsk
# Processing Record 21 of Set 7 : severo-kurilsk
# Processing Record 22 of Set 7 : wuzhou
# City not found. Skipping...
# Processing Record 23 of Set 7 : dromolaxia
# Processing Record 24 of Set 7 : guia de isora
# Processing Record 25 of Set 7 : ballina
# Processing Record 26 of Set 7 : whitianga
# Processing Record 27 of Set 7 : auki
# Processing Record 28 of Set 7 : husavik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 7 : nouadhibou
# City not found. Skipping...
# Processing Record 30 of Set 7 : san-pedro
# Processing Record 31 of Set 7 : kemerovo
# Processing Record 32 of Set 7 : velka nad velickou
# Processing Record 33 of Set 7 : shingu
# City not found. Skipping...
# Processing Record 34 of Set 7 : peterhead
# Processing Record 35 of Set 7 : port blair
# Processing Record 36 of Set 7 : san carlos de bariloche
# City not found. Skipping...
# Processing Record 37 of Set 7 : saint-francois
# Processing Record 38 of Set 7 : karratha
# Processing Record 39 of Set 7 : nicoya
# Processing Record 40 of Set 7 : susangerd
# Processing Record 41 of Set 7 : morant bay
# Processing Record 42 of Set 7 : norman wells
# Processing Record 43 of Set 7 : san rafael
# Processing Record 44 of Set 7 : geraldton
# Processing Record 45 of Set 7 : kamenka
# Processing Record 46 of Set 7 : taitung
# Processing Record 47 of Set 7 : cockburn town
# Processing Record 48 of Set 7 : crotone
# Processing Record 49 of Set 7 : carman
# Processing Record 50 of Set 7 : polunochnoye
# Processing Record 0 of Set 8 : rivadavia
# Processing Record 1 of Set 8 : bandar-e lengeh
# Processing Record 2 of Set 8 : biak
# Processing Record 3 of Set 8 : mugur-aksy
# Processing Record 4 of Set 8 : coihaique
# Processing Record 5 of Set 8 : ancud
# Processing Record 6 of Set 8 : nikolayevka
# Processing Record 7 of Set 8 : aykhal
# Processing Record 8 of Set 8 : bijar
# Processing Record 9 of Set 8 : avarua
# Processing Record 10 of Set 8 : las cruces
# Processing Record 11 of Set 8 : ofunato
# Processing Record 12 of Set 8 : mahina
# City not found. Skipping...
# Processing Record 13 of Set 8 : miri
# Processing Record 14 of Set 8 : kapit
# Processing Record 15 of Set 8 : griffith
# Processing Record 16 of Set 8 : conop
# Processing Record 17 of Set 8 : hofn
# Processing Record 18 of Set 8 : khani
# Processing Record 19 of Set 8 : angoche
# Processing Record 20 of Set 8 : mareeba
# Processing Record 21 of Set 8 : yumen
# Processing Record 22 of Set 8 : kindu
# Processing Record 23 of Set 8 : brae
# Processing Record 24 of Set 8 : sangar
# Processing Record 25 of Set 8 : waipawa
# Processing Record 26 of Set 8 : kuandian
# Processing Record 27 of Set 8 : aligudarz
# Processing Record 28 of Set 8 : guderup
# Processing Record 29 of Set 8 : alugan
# Processing Record 30 of Set 8 : saint anthony
# Processing Record 31 of Set 8 : komsomolskiy
# Processing Record 32 of Set 8 : asfi
# Processing Record 33 of Set 8 : vaitape
# Processing Record 34 of Set 8 : raudeberg
# Processing Record 35 of Set 8 : nemuro
# Processing Record 36 of Set 8 : williams lake
# Processing Record 37 of Set 8 : amahai
# City not found. Skipping...
# Processing Record 38 of Set 8 : san quintin
# Processing Record 39 of Set 8 : talnakh
# Processing Record 40 of Set 8 : bumba
# Processing Record 41 of Set 8 : gizo
# Processing Record 42 of Set 8 : hami
# Processing Record 43 of Set 8 : haines junction
# Processing Record 44 of Set 8 : mokhsogollokh
# Processing Record 45 of Set 8 : qaqortoq
# Processing Record 46 of Set 8 : murchison
# Processing Record 47 of Set 8 : gat
# Processing Record 48 of Set 8 : jacareacanga
# Processing Record 49 of Set 8 : kisangani
# Processing Record 50 of Set 8 : stepanov
# Processing Record 0 of Set 9 : cienaga
# Processing Record 1 of Set 9 : hof
# Processing Record 2 of Set 9 : constitucion
# Processing Record 3 of Set 9 : comodoro rivadavia
# Processing Record 4 of Set 9 : lasa
# Processing Record 5 of Set 9 : clyde river
# Processing Record 6 of Set 9 : makurdi
# Processing Record 7 of Set 9 : soto la marina
# Processing Record 8 of Set 9 : saldanha
# Processing Record 9 of Set 9 : reyes
# Processing Record 10 of Set 9 : tartagal
# Processing Record 11 of Set 9 : tashtagol
# City not found. Skipping...
# Processing Record 12 of Set 9 : laibin
# Processing Record 13 of Set 9 : biltine
# Processing Record 14 of Set 9 : nandu
# Processing Record 15 of Set 9 : neiafu
# Processing Record 16 of Set 9 : wonthaggi
# Processing Record 17 of Set 9 : tessalit
# Processing Record 18 of Set 9 : palana
# Processing Record 19 of Set 9 : villaviciosa
# Processing Record 20 of Set 9 : alihe
# City not found. Skipping...
# Processing Record 21 of Set 9 : komsomolets
# Processing Record 22 of Set 9 : santander jimenez
# City not found. Skipping...
# Processing Record 23 of Set 9 : uige
# Processing Record 24 of Set 9 : alice
# Processing Record 25 of Set 9 : tabou
# Processing Record 26 of Set 9 : batagay-alyta
# Processing Record 27 of Set 9 : usinsk
# Processing Record 28 of Set 9 : luanda
# Processing Record 29 of Set 9 : washougal
# Processing Record 30 of Set 9 : orange
# Processing Record 31 of Set 9 : nalgonda
# Processing Record 32 of Set 9 : petatlan
# Processing Record 33 of Set 9 : elat
# Processing Record 34 of Set 9 : mizan teferi
# Processing Record 35 of Set 9 : monrovia
# Processing Record 36 of Set 9 : zelenogorskiy
# Processing Record 37 of Set 9 : hervey bay
# Processing Record 38 of Set 9 : kalianget
# Processing Record 39 of Set 9 : rognan
# Processing Record 40 of Set 9 : saint-pierre
# Processing Record 41 of Set 9 : asau
# Processing Record 42 of Set 9 : bethel
# Processing Record 43 of Set 9 : palmeira
# Processing Record 44 of Set 9 : ukiah
# Processing Record 45 of Set 9 : hualmay
# Processing Record 46 of Set 9 : mecca
# Processing Record 47 of Set 9 : miyako
# Processing Record 48 of Set 9 : san antonio
# Processing Record 49 of Set 9 : boromo
# Processing Record 50 of Set 9 : krasnoselkup
# Processing Record 0 of Set 10 : obihiro
# Processing Record 1 of Set 10 : eskilstuna
# Processing Record 2 of Set 10 : leningradskiy
# Processing Record 3 of Set 10 : rosita
# Processing Record 4 of Set 10 : ribeiropolis
# Processing Record 5 of Set 10 : hambantota
# Processing Record 6 of Set 10 : batemans bay
# Processing Record 7 of Set 10 : demidov
# Processing Record 8 of Set 10 : port-cartier
# Processing Record 9 of Set 10 : vizinga
# Processing Record 10 of Set 10 : los llanos de aridane
# Processing Record 11 of Set 10 : pimentel
# Processing Record 12 of Set 10 : limbe
# Processing Record 13 of Set 10 : alofi
# Processing Record 14 of Set 10 : bom jesus da lapa
# Processing Record 15 of Set 10 : barberton
# Processing Record 16 of Set 10 : iqaluit
# Processing Record 17 of Set 10 : jibuti
# Processing Record 18 of Set 10 : broome
# Processing Record 19 of Set 10 : axim
# Processing Record 20 of Set 10 : sunam
# Processing Record 21 of Set 10 : lichinga
# Processing Record 22 of Set 10 : port augusta
# City not found. Skipping...
# Processing Record 23 of Set 10 : kemise
# Processing Record 24 of Set 10 : brunssum
# Processing Record 25 of Set 10 : vianopolis
# Processing Record 26 of Set 10 : strezhevoy
# Processing Record 27 of Set 10 : jalu
# Processing Record 28 of Set 10 : lamar
# Processing Record 29 of Set 10 : borgarnes
# Processing Record 30 of Set 10 : hollola
# Processing Record 31 of Set 10 : adrar
# Processing Record 32 of Set 10 : torbat-e jam
# Processing Record 33 of Set 10 : russell
# Processing Record 34 of Set 10 : gravdal
# Processing Record 35 of Set 10 : coahuayana
# Processing Record 36 of Set 10 : mana
# Processing Record 37 of Set 10 : buzmeyin
# Processing Record 38 of Set 10 : giyon
# Processing Record 39 of Set 10 : stephenville
# City not found. Skipping...
# Processing Record 40 of Set 10 : iskateley
# Processing Record 41 of Set 10 : necochea
# Processing Record 42 of Set 10 : esna
# Processing Record 43 of Set 10 : idar
# City not found. Skipping...
# Processing Record 44 of Set 10 : otautau
# Processing Record 45 of Set 10 : sterling
# Processing Record 46 of Set 10 : tikrit
# Processing Record 47 of Set 10 : amapa
# Processing Record 48 of Set 10 : tyumentsevo
# Processing Record 49 of Set 10 : takoradi
# Processing Record 50 of Set 10 : hudson bay
# Processing Record 0 of Set 11 : atar
# Processing Record 1 of Set 11 : bembibre
# Processing Record 2 of Set 11 : mushie
# Processing Record 3 of Set 11 : general roca
# Processing Record 4 of Set 11 : kavaratti
# Processing Record 5 of Set 11 : saryg-sep
# Processing Record 6 of Set 11 : grand gaube
# Processing Record 7 of Set 11 : olinda
# City not found. Skipping...
# Processing Record 8 of Set 11 : muros
# Processing Record 9 of Set 11 : la ronge
# Processing Record 10 of Set 11 : manggar
# Processing Record 11 of Set 11 : warri
# Processing Record 12 of Set 11 : ahwa
# Processing Record 13 of Set 11 : ostersund
# City not found. Skipping...
# Processing Record 14 of Set 11 : huilong
# Processing Record 15 of Set 11 : ixtapa
# Processing Record 16 of Set 11 : tripoli
# Processing Record 17 of Set 11 : victor harbor
# Processing Record 18 of Set 11 : togur
# Processing Record 19 of Set 11 : menongue
# Processing Record 20 of Set 11 : pisco
# Processing Record 21 of Set 11 : lodja
# Processing Record 22 of Set 11 : lockhart
# Processing Record 23 of Set 11 : gold coast
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 11 : havre-saint-pierre
# Processing Record 25 of Set 11 : agapovka
# Processing Record 26 of Set 11 : ous
# Processing Record 27 of Set 11 : yelizovo
# Processing Record 28 of Set 11 : rabo de peixe
# Processing Record 29 of Set 11 : manavalakurichi
# Processing Record 30 of Set 11 : lixourion
# Processing Record 31 of Set 11 : shalinskoye
# Processing Record 32 of Set 11 : sedalia
# Processing Record 33 of Set 11 : aljezur
# Processing Record 34 of Set 11 : pine bluff
# Processing Record 35 of Set 11 : shimsk
# Processing Record 36 of Set 11 : humaita
# Processing Record 37 of Set 11 : gatesville
# Processing Record 38 of Set 11 : byron bay
# Processing Record 39 of Set 11 : san juan
# Processing Record 40 of Set 11 : navolato
# Processing Record 41 of Set 11 : phichit
# Processing Record 42 of Set 11 : quatre cocos
# Processing Record 43 of Set 11 : kencong
# Processing Record 44 of Set 11 : mwene-ditu
# Processing Record 45 of Set 11 : la rioja
# Processing Record 46 of Set 11 : mirwah
# Processing Record 47 of Set 11 : klyuchi
# Processing Record 48 of Set 11 : kpandae
# Processing Record 49 of Set 11 : banda aceh
# Processing Record 50 of Set 11 : aksarka
# Processing Record 0 of Set 12 : napa
# Processing Record 1 of Set 12 : khartoum
# Processing Record 2 of Set 12 : solnechnyy
# Processing Record 3 of Set 12 : uyuni
# Processing Record 4 of Set 12 : tshikapa
# Processing Record 5 of Set 12 : yershov
# Processing Record 6 of Set 12 : faya
# Processing Record 7 of Set 12 : chara
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# # Convert Raw Data to DataFrame
#
# Export the city data into a .csv.
# Display the DataFrame

# %%
# Create a panda data frame using data retrieved
weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
# Count data
weather_dict.count()
# Out:
# City          568
# Cloudiness    568
# Country       568
# Date          568
# Humidity      568
# Lat           568
# Lng           568
# Max Temp      568
# Wind Speed    568
# dtype: int64

# %%
# Display the Data Frame
weather_dict
# Out:
#              City  Cloudiness Country        Date  Humidity      Lat  \
# 0          Yulara          98      AU  1612125754        21 -25.2406
# 1    Ponta do Sol           0      PT  1612125755        73  32.6667
# 2       Belyy Yar          62      RU  1612125755        76  53.6039
# 3        Colorado         100      BR  1612125755        82 -22.8375
# 4            Lebu           2      CL  1612125620        78 -37.6167
# ..            ...         ...     ...         ...       ...      ...
# 563         Uyuni           0      BO  1612125825        22 -20.4597
# 564      Tshikapa         100      CD  1612125825        92  -6.4167
# 565       Yershov         100      RU  1612125826        95  51.3513
# 566          Faya           0      SA  1612125826        47  18.3851
# 567         Chara         100      RU  1612125826        73  56.9064
#
#           Lng  Max Temp  Wind Speed
# 0    130.9889     84.20       10.36
# 1    -17.1000     57.99        3.00
# 2     91.3903    -23.80        0.51
# 3    -51.9731     77.83        3.89
# 4    -73.6500     60.60       16.69
# ..        ...       ...         ...
# 563  -66.8250     65.97       10.25
# 564   20.8000     72.25        1.45
# 565   48.2766     33.51       16.51
# 566   42.4509     57.20        2.73
# 567  118.2631    -35.32        2.98
#
# [568 rows x 9 columns]

# %%
# Save city data into a csv file
weather_dict.to_csv("output_data/cities.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-2da19d485a00> in <module>
#       1 # Save city data into a csv file
# ----> 2 weather_dict.to_csv("output_data/cities.csv", index = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/cities.csv'

# %% [markdown]
# # Plotting the Data
#
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# Save the plotted figures as .pngs.

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)
# Out:
# (-5.0, 105.0)

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)
# Out:
# (-2.0, 50.0)

# %% [markdown]
# # Linear Regression

# %%
#Divide the Hemispheres and print with line regression 

northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")
# Out:
# The r-squared is : -0.86
# Text(0, 0.5, 'Max Temp (F)')

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")
# Out:
# The r-squared is : 0.63
# Text(0, 0.5, 'Max Temp (F)')

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")
# Out:
# The r-squared is : 0.36
# Text(0, 0.5, 'Humidity (%)')

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")
# Out:
# The r-squared is : 0.24
# Text(0, 0.5, 'Humidity (%)')

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")
# Out:
# The r-squared is : 0.19
# Text(0, 0.5, 'Cloudiness (%)')

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")
# Out:
# The r-squared is : -0.0
# Text(0, 0.5, 'Wind Speed (mph)')

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")
# Out:
# The r-squared is : -0.09
# Text(0, 0.5, 'Wind Speed (mph)')
